# %% [markdown]
# # BaseLine Code
#
# - 약 106개의 이미지만을 사용하여 만든 baseline code
#
# ## Step 1. 실험환경 set-up
#
# #### 라이브러리 실행

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %% [markdown]
# #### 필요한 변수들 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# BATCH_SIZE 변수
BATCH_SIZE = 32

# 이미지 사이즈 변수
IMAGE_SIZE = [256, 256]

# EPOCH 크기 변수
EPOCHS = 30

# %% [markdown]
# ## Step 2. 데이터 준비하기
#
# 먼저 아래의 링크에서 데이터를 다운 받을 것
#
# https://drive.google.com/drive/folders/1Pi5qyX080zY2IdGT1TvvLraBO9DHBxJl?usp=sharing
#
# 받은 후 터미널 창에 아래의 명령어들을 차례로 입력
#
# ```
# $ cd ~/Downloads && cp CellPin ~/aiffel
# ```
#
# #### 데이터의 개수 확인

# %%
# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel/CellPin')
print(ROOT_PATH)

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*'))
# val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*'))

print(len(train_filenames))
# print(len(test_filenames))
# print(len(val_filenames))
# Out:
# /home/aiffel-dj52/aiffel/CellPin
# 188

# %% [markdown]
# #### train과 validation을 80:20으로 분할

# %%
# filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*')))

train_filenames, test_filenames = train_test_split(train_filenames, test_size=0.2)

print(len(train_filenames))
print(len(test_filenames))
# Out:
# 150
# 38

# %%
# filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*')))

train_filenames, val_filenames = train_test_split(train_filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 120
# 30

# %% [markdown]
# #### train 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in train_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 25
# CPE images count in training set: 95

# %% [markdown]
# #### val 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in val_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in val_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 7
# CPE images count in training set: 23

# %% [markdown]
# #### test 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in test_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in test_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 7
# CPE images count in training set: 31

# %% [markdown]
# #### tf.data 인스턴스를 만들기

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# #### train data와 val data의 개수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 120
# Validating images count: 30

# %% [markdown]
# #### 라벨 이름들 확인

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/train/*"))])
print(CLASS_NAMES)
# Out:
# ['cpe' 'normal']

# %% [markdown]
# #### 라벨링 함수를 만들어 보기

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "cpe"

# %% [markdown]
# #### decode_img 함수와 process_path 함수를 만들기

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
# #### train과 val에 함수들 적용해주기

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# #### 전처리 함수 만들기 및 적용

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# #### Image shape를 변경 체크하기

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (32, 256, 256, 3)
# Label:  [False  True  True  True False False  True  True  True False  True  True
#   True  True  True  True False  True False  True  True  True False  True
#   True  True  True  True  True  True  True False]

# %% [markdown]
# #### test 데이터 셋도 만들어 보기 & 데이터의 갯수 확인

# %%
# test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/test/*/*'))
# TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_list_ds = tf.data.Dataset.from_tensor_slices(test_filenames)
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# print(TEST_IMAGE_COUNT)

# %% [markdown]
# ## Step 3. 데이터 시각화
#
# #### 16개의 샘플 꺼내서 확인

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("CPE")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# #### model building

# %%
resnet_layer = [
    tf.keras.applications.ResNet152V2(include_top = False,
                                      weights = "imagenet",
                                      input_shape = (256, 256, 3),
                                      classes = 1,
                                      classifier_activation = "softmax")
]

fc_layer = [
    tf.keras.layers.GlobalMaxPool2D(),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Activation('softmax')
]

resnet152 = tf.keras.models.Sequential(resnet_layer + fc_layer)

# %%
resnet152.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet152v2 (Functional)     (None, 8, 8, 2048)        58331648
# _________________________________________________________________
# global_max_pooling2d (Global (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 58,333,697
# Trainable params: 58,189,953
# Non-trainable params: 143,744
# _________________________________________________________________

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리
#
# #### 이 weight들은 'Normal'과 'Cpe' 전체 데이터 건수에 반비례하도록 설정

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_CPE)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 8.57
# Weight for class 1: 1.94

# %% [markdown]
# ## Step 6. 모델 훈련
#
# #### GPU사용하여 model complie

# %%
with tf.device('/GPU:0'):
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    resnet152.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
    # early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 2, restore_best_weights = True)
    check_point = tf.keras.callbacks.ModelCheckpoint(ROOT_PATH + '/pre_training_model/best_model_test.h5')

# %%
# tf.keras.utils.plot_model(resnet152, to_file = "model.png", show_shapes = True, show_layer_names = False)

# %% [markdown]
# #### 모델 fitting

# %%
with tf.device('/GPU:0'):
    history = resnet152.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=2, # VAL_IMG_COUNT // BATCH_SIZE
        class_weight=class_weight,
        callbacks=[check_point]
    )
# Out:
# WARNING:tensorflow:From /home/aiffel-dj52/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/30
# 3/3 [==============================] - 84s 21s/step - loss: 6.9293 - accuracy: 0.8229 - precision: 0.8229 - recall: 1.0000 - val_loss: 15.7469 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# /home/aiffel-dj52/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/30
# 3/3 [==============================] - 54s 20s/step - loss: 13.1467 - accuracy: 0.7604 - precision: 0.7604 - recall: 1.0000 - val_loss: 37.0806 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 3/30
# 3/3 [==============================] - 54s 20s/step - loss: 4.8397 - accuracy: 0.7604 - precision: 0.7604 - recall: 1.0000 - val_loss: 3787.5134 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 4/30
# 3/3 [==============================] - 53s 20s/step - loss: 1.3747 - accuracy: 0.8229 - precision: 0.8229 - recall: 1.0000 - val_loss: 37163112.0000 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 5/30
# 3/3 [==============================] - 54s 20s/step - loss: 25.6052 - accuracy: 0.7917 - precision: 0.7917 - recall: 1.0000 - val_loss: 217483552.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 6/30
# 3/3 [==============================] - 54s 20s/step - loss: 1.2581 - accuracy: 0.7812 - precision: 0.7812 - recall: 1.0000 - val_loss: 2191287552.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 7/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.6212 - accuracy: 0.8229 - precision: 0.8229 - recall: 1.0000 - val_loss: 24832159744.0000 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 1.0000
# Epoch 8/30
# 3/3 [==============================] - 54s 20s/step - loss: 1.5553 - accuracy: 0.8021 - precision: 0.8021 - recall: 1.0000 - val_loss: 26899918848.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 9/30
# 3/3 [==============================] - 54s 20s/step - loss: 1.6656 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 26212331520.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 10/30
# 3/3 [==============================] - 54s 20s/step - loss: 1.0477 - accuracy: 0.8021 - precision: 0.8021 - recall: 1.0000 - val_loss: 6483126272.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 11/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.4706 - accuracy: 0.7708 - precision: 0.7708 - recall: 1.0000 - val_loss: 1196865024.0000 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 12/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.5504 - accuracy: 0.8333 - precision: 0.8333 - recall: 1.0000 - val_loss: 379006816.0000 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 13/30
# 3/3 [==============================] - 53s 20s/step - loss: 0.4492 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 5295298.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 14/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1397 - accuracy: 0.8125 - precision: 0.8125 - recall: 1.0000 - val_loss: 37094128.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 15/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1907 - accuracy: 0.7917 - precision: 0.7917 - recall: 1.0000 - val_loss: 30648436.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 16/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1614 - accuracy: 0.8021 - precision: 0.8021 - recall: 1.0000 - val_loss: 20201328.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 17/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.2132 - accuracy: 0.7604 - precision: 0.7604 - recall: 1.0000 - val_loss: 11256367.0000 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 18/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1415 - accuracy: 0.7812 - precision: 0.7812 - recall: 1.0000 - val_loss: 6434186.0000 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 19/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.6603 - accuracy: 0.8333 - precision: 0.8333 - recall: 1.0000 - val_loss: 3201510.7500 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 20/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1760 - accuracy: 0.7812 - precision: 0.7812 - recall: 1.0000 - val_loss: 1190917.2500 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 21/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1590 - accuracy: 0.8229 - precision: 0.8229 - recall: 1.0000 - val_loss: 531691.1875 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 22/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.5637 - accuracy: 0.7708 - precision: 0.7708 - recall: 1.0000 - val_loss: 430075.8125 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 23/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1706 - accuracy: 0.8125 - precision: 0.8125 - recall: 1.0000 - val_loss: 290262.5625 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 24/30
# 3/3 [==============================] - 53s 20s/step - loss: 0.2278 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 180896.0938 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 25/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.4927 - accuracy: 0.8021 - precision: 0.8021 - recall: 1.0000 - val_loss: 109279.2188 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 1.0000
# Epoch 26/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.1697 - accuracy: 0.7812 - precision: 0.7812 - recall: 1.0000 - val_loss: 67265.0625 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 27/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.5090 - accuracy: 0.8229 - precision: 0.8229 - recall: 1.0000 - val_loss: 44460.9297 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 28/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.2836 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 28624.1172 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 29/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.3751 - accuracy: 0.8333 - precision: 0.8333 - recall: 1.0000 - val_loss: 17036.2051 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 1.0000
# Epoch 30/30
# 3/3 [==============================] - 54s 20s/step - loss: 0.0747 - accuracy: 0.7708 - precision: 0.7708 - recall: 1.0000 - val_loss: 14359.0107 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000

# %% [markdown]
# ## Step 7. 결과 확인 및 시각화

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## Step 8. 최종 Test dataset 검정하기

# %%
model = tf.keras.models.load_model(ROOT_PATH + '/pre_training_model/best_model_test.h5')
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 7s 533ms/step - loss: 10667.7646 - accuracy: 0.8158 - precision: 0.8158 - recall: 1.0000

# %% [markdown]
# ## Discussion
