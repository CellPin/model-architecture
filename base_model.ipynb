# %% [markdown]
# # BaseLine Code
#
# - 약 106개의 이미지만을 사용하여 만든 baseline code
#
# ## Step 1. 실험환경 set-up
#
# #### 라이브러리 실행

# %%
from tensorflow.keras             import utils, regularizers
from tensorflow.keras.models      import Sequential, load_model
from tensorflow.keras.layers      import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers  import Adam
from tensorflow.keras.constraints import MaxNorm

import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %% [markdown]
# #### 필요한 변수들 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# BATCH_SIZE 변수
BATCH_SIZE = 32

# 이미지 사이즈 변수
IMAGE_SIZE = [256, 256]

# EPOCH 크기 변수
EPOCHS = 30

# %% [markdown]
# ## Step 2. 데이터 준비하기
#
# 먼저 아래의 링크에서 데이터를 다운 받을 것
#
# https://drive.google.com/drive/folders/1Pi5qyX080zY2IdGT1TvvLraBO9DHBxJl?usp=sharing
#
# 받은 후 터미널 창에 아래의 명령어들을 차례로 입력
#
# ```
# $ cd ~/Downloads && cp CellPin ~/aiffel
# ```
#
# #### 데이터의 개수 확인

# %%
# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel/CellPin')
print(ROOT_PATH)

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*'))
# val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*'))

print(len(train_filenames))
# print(len(test_filenames))
# print(len(val_filenames))
# Out:
# /home/aiffel-dj52/aiffel/CellPin
# 188

# %% [markdown]
# #### train과 validation을 80:20으로 분할

# %%
# filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*')))

train_filenames, test_filenames = train_test_split(train_filenames, test_size=0.2)

print(len(train_filenames))
print(len(test_filenames))
# Out:
# 150
# 38

# %%
# filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*')))

train_filenames, val_filenames = train_test_split(train_filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 120
# 30

# %% [markdown]
# #### train 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in train_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 28
# CPE images count in training set: 92

# %% [markdown]
# #### val 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in val_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in val_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 5
# CPE images count in training set: 25

# %% [markdown]
# #### test 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in test_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in test_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 6
# CPE images count in training set: 32

# %% [markdown]
# #### tf.data 인스턴스를 만들기

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# #### train data와 val data의 개수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 120
# Validating images count: 30

# %% [markdown]
# #### 라벨 이름들 확인

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/train/*"))])
print(CLASS_NAMES)
# Out:
# ['cpe' 'normal']

# %% [markdown]
# #### 라벨링 함수를 만들어 보기

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "cpe"

# %% [markdown]
# #### decode_img 함수와 process_path 함수를 만들기

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
# #### train과 val에 함수들 적용해주기

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# #### 전처리 함수 만들기 및 적용

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# #### Image shape를 변경 체크하기

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (32, 256, 256, 3)
# Label:  [ True False  True  True  True False False  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True False
#  False  True  True False False  True  True  True]

# %% [markdown]
# #### test 데이터 셋도 만들어 보기 & 데이터의 갯수 확인

# %%
# test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/test/*/*'))
# TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_list_ds = tf.data.Dataset.from_tensor_slices(test_filenames)
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# print(TEST_IMAGE_COUNT)

# %% [markdown]
# ## Step 3. 데이터 시각화
#
# #### 16개의 샘플 꺼내서 확인

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("CPE")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# #### model building(VGG19)

# %%
conv_layer = [    
    # convolution and then pooling
    Conv2D(20, (7, 7), input_shape=(1024,1360,1), name='first_conv_layer',padding='valid'),
    Activation('relu'),
    MaxPooling2D(pool_size=(10, 10), padding='valid'),

    # convolution and then pooling
    Conv2D(25, (5, 5), name='second_conv_layer', padding='valid'),
    Activation('relu'),
    MaxPooling2D(pool_size=(6, 6), padding='valid'),
    
    # convolution and then pooling
    Conv2D(30, (3, 3), name='third_conv_layer', padding='valid'),
    Activation('relu'),
    MaxPooling2D(pool_size=(6, 6), padding='valid')
]

fc_layer = [
    # flatten and connect with three fully connected layer
    Flatten(),
    Dense(100, name='fc_layer_100_1'),
    Activation('sigmoid'),
    Dense(100, name='fc_layer_100_2',kernel_constraint= MaxNorm(1.)),
    Activation('sigmoid'),
    Dense(100, name='fc_layer_100_3',kernel_regularizer=regularizers.l2(0.01)),
    Activation('sigmoid'),
 
    # conneted with smaller fully connected layer
    # with the same number of neurons as the number of classes
    Dense(2, name='fc_layer_2'),
    Activation('softmax')
]

model = Sequential(conv_layer + fc_layer)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# first_conv_layer (Conv2D)    (None, 1018, 1354, 20)    1000
# _________________________________________________________________
# activation_4 (Activation)    (None, 1018, 1354, 20)    0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 101, 135, 20)      0
# _________________________________________________________________
# second_conv_layer (Conv2D)   (None, 97, 131, 25)       12525
# _________________________________________________________________
# activation_5 (Activation)    (None, 97, 131, 25)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 21, 25)        0
# _________________________________________________________________
# third_conv_layer (Conv2D)    (None, 14, 19, 30)        6780
# _________________________________________________________________
# activation_6 (Activation)    (None, 14, 19, 30)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 3, 30)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 180)               0
# _________________________________________________________________
# fc_layer_100_1 (Dense)       (None, 100)               18100
# _________________________________________________________________
# activation_7 (Activation)    (None, 100)               0
# _________________________________________________________________
# fc_layer_100_2 (Dense)       (None, 100)               10100
# _________________________________________________________________
# activation_8 (Activation)    (None, 100)               0
# _________________________________________________________________
# fc_layer_100_3 (Dense)       (None, 100)               10100
# _________________________________________________________________
# activation_9 (Activation)    (None, 100)               0
# _________________________________________________________________
# fc_layer_2 (Dense)           (None, 2)                 202
# _________________________________________________________________
# activation_10 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 58,807
# Trainable params: 58,807
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리
#
# #### 이 weight들은 'Normal'과 'Cpe' 전체 데이터 건수에 반비례하도록 설정

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_CPE)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 10.00
# Weight for class 1: 1.88

# %% [markdown]
# ## Step 6. 모델 훈련
#
# #### GPU사용하여 model complie

# %%
with tf.device('/GPU:0'):
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
    # early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 2, restore_best_weights = True)
    check_point = tf.keras.callbacks.ModelCheckpoint(ROOT_PATH + '/pre_training_model/best_model_test.h5')

# %%
# tf.keras.utils.plot_model(model, to_file = "model.png", show_shapes = True, show_layer_names = False)

# %% [markdown]
# #### 모델 fitting

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=2, # VAL_IMG_COUNT // BATCH_SIZE
        class_weight=class_weight,
        callbacks=[check_point]
    )
# Out:
# WARNING:tensorflow:From /home/aiffel-dj52/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/30
# 3/3 [==============================] - 75s 21s/step - loss: 10.4576 - accuracy: 0.7708 - precision: 0.7708 - recall: 1.0000 - val_loss: 0.6981 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 2/30
# 3/3 [==============================] - 57s 21s/step - loss: 9.1028 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 0.7724 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 1.0000
# Epoch 3/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.2323 - accuracy: 0.8333 - precision: 0.8333 - recall: 1.0000 - val_loss: 0.6933 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 4/30
# 3/3 [==============================] - 57s 21s/step - loss: 3.1680 - accuracy: 0.6667 - precision: 0.6667 - recall: 1.0000 - val_loss: 0.7028 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 5/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.3510 - accuracy: 0.8125 - precision: 0.8125 - recall: 1.0000 - val_loss: 0.7115 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 6/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.4019 - accuracy: 0.8021 - precision: 0.8021 - recall: 1.0000 - val_loss: 0.7238 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 1.0000
# Epoch 7/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5972 - accuracy: 0.7604 - precision: 0.7604 - recall: 1.0000 - val_loss: 0.7804 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 8/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.6515 - accuracy: 0.7292 - precision: 0.7292 - recall: 1.0000 - val_loss: 1.1020 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 9/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.4547 - accuracy: 0.8021 - precision: 0.8021 - recall: 1.0000 - val_loss: 0.8355 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 10/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.6310 - accuracy: 0.7396 - precision: 0.7396 - recall: 1.0000 - val_loss: 0.7870 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 11/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5129 - accuracy: 0.7708 - precision: 0.7708 - recall: 1.0000 - val_loss: 0.7991 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 12/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.4240 - accuracy: 0.7917 - precision: 0.7917 - recall: 1.0000 - val_loss: 0.7989 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 1.0000
# Epoch 13/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.6235 - accuracy: 0.7396 - precision: 0.7396 - recall: 1.0000 - val_loss: 0.8415 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 14/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.4341 - accuracy: 0.7917 - precision: 0.7917 - recall: 1.0000 - val_loss: 0.8748 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 15/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5888 - accuracy: 0.7396 - precision: 0.7396 - recall: 1.0000 - val_loss: 0.9131 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 16/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5257 - accuracy: 0.7604 - precision: 0.7604 - recall: 1.0000 - val_loss: 0.9188 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 17/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5309 - accuracy: 0.7604 - precision: 0.7604 - recall: 1.0000 - val_loss: 0.9483 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 18/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.3965 - accuracy: 0.8125 - precision: 0.8125 - recall: 1.0000 - val_loss: 0.8904 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 1.0000
# Epoch 19/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5521 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 0.8683 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 20/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5641 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 21/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.3546 - accuracy: 0.8125 - precision: 0.8125 - recall: 1.0000 - val_loss: 0.8388 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 22/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.7131 - accuracy: 0.7083 - precision: 0.7083 - recall: 1.0000 - val_loss: 0.8482 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 23/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5616 - accuracy: 0.7500 - precision: 0.7500 - recall: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 1.0000
# Epoch 24/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.3002 - accuracy: 0.8333 - precision: 0.8333 - recall: 1.0000 - val_loss: 0.8724 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 25/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.6275 - accuracy: 0.7292 - precision: 0.7292 - recall: 1.0000 - val_loss: 0.8855 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 26/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.4635 - accuracy: 0.7812 - precision: 0.7812 - recall: 1.0000 - val_loss: 0.8860 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 27/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.5886 - accuracy: 0.7396 - precision: 0.7396 - recall: 1.0000 - val_loss: 0.9019 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 1.0000
# Epoch 28/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.3789 - accuracy: 0.8125 - precision: 0.8125 - recall: 1.0000 - val_loss: 0.8961 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 29/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.6474 - accuracy: 0.7188 - precision: 0.7188 - recall: 1.0000 - val_loss: 0.8942 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000
# Epoch 30/30
# 3/3 [==============================] - 57s 21s/step - loss: 2.4680 - accuracy: 0.7812 - precision: 0.7812 - recall: 1.0000 - val_loss: 0.9031 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 1.0000

# %% [markdown]
# ## Step 7. 결과 확인 및 시각화

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## Step 8. 최종 Test dataset 검정하기

# %%
model = tf.keras.models.load_model(ROOT_PATH + '/pre_training_model/best_model_test.h5')
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 5s 645ms/step - loss: 0.9022 - accuracy: 0.8421 - precision: 0.8421 - recall: 1.0000

# %% [markdown]
# ## Discussion
